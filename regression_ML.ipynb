# %%
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn import svm, preprocessing

# %%
df = pd.read_csv('diamonds.csv',index_col=0)
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [raw]
# df['cut'].astype('category').cat.codes
# #used for random categorization

# %%
cut_class_dict = {'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}
clarity_dict = {"I3": 1, "I2": 2, "I1": 3, "SI2": 4, "SI1": 5, "VS2": 6, "VS1": 7, "VVS2": 8, "VVS1": 9, "IF": 10, "FL": 11}
color_dict = {"J": 1,"I": 2,"H": 3,"G": 4,"F": 5,"E": 6,"D": 7}

# %%
df['cut'] = df['cut'].map(cut_class_dict)
df['clarity'] = df['clarity'].map(clarity_dict)
df['color'] = df['color'].map(color_dict)
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 1   0.23    5      6        4   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21    4      6        5   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23    2      6        7   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29    4      2        6   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31    2      1        4   63.3   58.0    335  4.34  4.35  2.75

# %%
df = sk.utils.shuffle(df)
x = df.drop('price',axis=1).values
y = df['price'].values

# %%
x = preprocessing.scale(x)
# Out:
# array([[ 2.15621409, -0.80969515, -2.00213083, ...,  1.87104269,
#          1.94853963,  1.94315031],
#        [-1.00829713,  0.08588908, -1.41427211, ..., -1.21342259,
#         -1.15094846, -1.11767377],
#        [-1.05049061,  0.98147332,  1.52502147, ..., -1.29365434,
#         -1.29103831, -1.23103762],
#        ...,
#        [-1.15597432, -0.80969515,  0.34930404, ..., -1.49869105,
#         -1.4486394 , -1.47193581],
#        [-0.56526556,  0.98147332, -0.8264134 , ..., -0.46459287,
#         -0.44174356, -0.4658316 ],
#        [ 0.48957152,  0.98147332,  0.34930404, ...,  0.73888347,
#          0.6789753 ,  0.6252955 ]])

# %%
test_size = 200
x_train = x[:-test_size] 
y_train = y[:-test_size]
x_test = x[-test_size:]
y_test = y[-test_size:]

# %%
clf = svm.SVR(kernel='linear')
clf.fit(x_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
clf.score(x_test,y_test)
# Out:
# 0.849811720901629

# %%
for x,y in zip(x_test,y_test):
    print(f"Model: {clf.predict([x])[0]}, Actual:{y}")
# Out:
# Model: 2046.8853882721573, Actual:1808
# Model: 1250.5961256571763, Actual:1312
# Model: 1361.1021518109342, Actual:1332
# Model: 5184.337969877957, Actual:6050
# Model: 742.4096061712612, Actual:773
# Model: 5514.895298957312, Actual:6112
# Model: 3415.3321991519288, Actual:4029
# Model: 5514.066712454183, Actual:7351
# Model: 6819.240916694167, Actual:9110
# Model: 2927.301450060205, Actual:2435
# Model: 1713.0007115830415, Actual:1243
# Model: 963.1125498025399, Actual:862
# Model: 945.3489223684114, Actual:764
# Model: 7162.754384085074, Actual:8069
# Model: 225.9688290766194, Actual:698
# Model: 785.603765053304, Actual:1066
# Model: 1160.2410574658593, Actual:1114
# Model: 2789.522511593503, Actual:1968
# Model: 4530.491303898133, Actual:3991
# Model: 8788.58480613313, Actual:12951
# Model: 4792.337922622963, Actual:4805
# Model: 4111.337656435859, Actual:4067
# Model: 6218.406283686038, Actual:5267
# Model: 1877.2339183611766, Actual:1580
# ...

# %%
a=[1,2,3]
b=[2,4,6,3]
list(zip(a,b))
# Out:
# [(1, 2), (2, 4), (3, 6)]

# %%
clf.predict([x_test[1],x_test[2]])
# Out:
# array([1250.59612566, 1361.10215181])

# %%
clff = svm.SVR(kernel='rbf')
clff.fit(x_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
print(clff.score(x_test,y_test))
for x,y in zip(x_test,y_test):
    print(f"Model: {clff.predict([x])[0]}, Actual:{y}")
# Out:
# 0.6273283666648998
# Model: 1761.4042816198125, Actual:1808
# Model: 1583.8529621976081, Actual:1312
# Model: 1473.5031470283743, Actual:1332
# Model: 3956.9056256951235, Actual:6050
# Model: 746.8806644308297, Actual:773
# Model: 5155.0204261103645, Actual:6112
# Model: 3174.3713889226906, Actual:4029
# Model: 6057.213506089542, Actual:7351
# Model: 6234.12419327099, Actual:9110
# Model: 2791.5945862224844, Actual:2435
# Model: 1406.6637390448873, Actual:1243
# Model: 994.2854245673343, Actual:862
# Model: 1160.194113181375, Actual:764
# Model: 6456.842030548663, Actual:8069
# Model: 714.2147012099117, Actual:698
# Model: 1235.6457195340795, Actual:1066
# Model: 1346.7373038795567, Actual:1114
# Model: 2488.955238312239, Actual:1968
# Model: 4409.314938756877, Actual:3991
# Model: 7412.669684563281, Actual:12951
# Model: 4021.7124652010434, Actual:4805
# Model: 3709.0331738110126, Actual:4067
# Model: 5272.851004159114, Actual:5267
# Model: 1810.6764129755584, Actual:1580
# ...
