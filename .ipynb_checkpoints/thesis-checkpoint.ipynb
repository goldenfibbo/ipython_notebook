# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
#from matplotlib import rc
import requests as rq
from __future__ import unicode_literals
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['figure.dpi'] = 600
#plt.rcParams['font.sans-serif']=['SimSun']
plt.rcParams['font.family']=['KaiTi']
#plt.rcParams['font.size']=5
plt.rcParams['font.style']='normal'
plt.rcParams['axes.unicode_minus']=False
matplotlib.rcParams['xtick.direction'] = 'in'
matplotlib.rcParams['ytick.direction'] = 'in' 
matplotlib.rcParams['text.usetex'] = False
#matplotlib.rcParams['text.latex.unicode'] = True
#matplotlib.rcParams['text.latex.preamble'] = [
#    '\\usepackage{CJK}',
#    r'\AtBeginDocument{\begin{CJK}{UTF8}{gbsn}}',
#    r'\AtEndDocument{\end{CJK}}',
#]

import matplotlib.ticker as mtick
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
web = rq.get("https://www.efunda.com/materials/elements/TC_Table.cfm?Element_ID=Si")
dfs = pd.read_html(web.text)

# %%
si_tc = dfs[3]
si_tc.drop(index=0,inplace=True)

# %%
si_tc.drop(index=1,inplace=True)

# %%
si_tc.rename(columns={0:'Temperature(K)',1:'Pressure(Pa)',2:'Thermal Conductivity'},inplace=True)

# %%
si_tc.head()
# Out:
#   Temperature(K) Pressure(Pa) Thermal Conductivity
# 2              1       101325                 6.93
# 3              2       101325                 45.4
# 4              3       101325                  138
# 5              4       101325                  297
# 6              5       101325                  527

# %%
si_tc.set_index('Temperature(K)',inplace=True)

# %%
tc = pd.to_numeric(si_tc['Thermal Conductivity'])
y = tc.to_list()
x = tc.index.astype(float).to_list()
plt.loglog(x,y,'m-',linewidth=1)
plt.loglog(x,y,'m+')
plt.xlabel('温度(K)')
plt.ylabel('热导率(W/mK)')
#plt.xscale('log')
#plt.yscale('log')
plt.show()

# %%
cut_ene = pd.DataFrame([i-43.22 for i in [-0.000338,-0.101050,-0.155293,-0.171120,-0.178534,-0.179486,-0.179376]],np.array(np.arange(200,501,50)))

# %%
cut_ene.rename(columns={0:'总能量'},inplace=True)

# %%
cut_ene
# Out:
#            总能量
# 200 -43.220338
# 250 -43.321050
# 300 -43.375293
# 350 -43.391120
# 400 -43.398534
# 450 -43.399486
# 500 -43.399376

# %%
cut_ene.plot(color='k',legend='')
plt.xlabel('截断能量/eV',size=15)
plt.ylabel('能量/eV',size=15)
plt.yticks(fontproperties = 'Times New Roman', size = 14)
plt.xticks(fontproperties = 'Times New Roman', size = 14)
#plt.savefig('/home/thoughts/git/thesis/fini-thesis/fig/cut-ene.png',bbox_inches='tight')
plt.savefig('C:/Users/thoughts/Documents/GitHub/thesis/defense/cut-ene.png',bbox_inches='tight')
ax = plt.gca()
#ax.yaxis.get_major_formatter().set_powerlimits((0,1))
fmt='%.3f'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
plt.show()

# %%
k_ene = pd.DataFrame([-43.379475,-43.398626,-43.399453,-43.399491,-43.399493],np.array(np.arange(4,13,2)))

# %%
k_ene.rename(columns={0:'能量'},inplace=True)

# %%
k_ene.plot(color='k',legend='')
plt.xlabel('每方向波矢网格节点数',size=15)
plt.ylabel('能量/eV',size=15)
plt.yticks(fontproperties = 'Times New Roman', size = 14)
plt.xticks(fontproperties = 'Times New Roman', size = 14)
#plt.savefig('/home/thoughts/git/thesis/fini-thesis/fig/k-ene.png',bbox_inches='tight')
plt.savefig('C:/Users/thoughts/Documents/GitHub/thesis/defense/k-ene.png',bbox_inches='tight')
#plt.legend('total energy',loc='best')
ax = plt.gca()
#ax.yaxis.get_major_formatter().set_powerlimits((0,1))
fmt='%.3f'
yticks = mtick.FormatStrFormatter(fmt)
ax.yaxis.set_major_formatter(yticks)
plt.show()

# %%
5.30   -42.968477
5.34   -43.154564
5.38   -43.285813
5.42   -43.365873
5.46   -43.398229
5.50   -43.386254
5.54   -43.332929
5.58   -43.241342
5.62   -43.114322
5.66   -42.954578
5.70   -42.764700
5.74   -42.547132
5.78   -42.304215
5.82   -42.038127
5.86   -41.750968
5.90   -41.444806

# %%
np.arange(5.30,5.91,0.04)**(-3)
# Out:
# array([0.00671695, 0.00656714, 0.00642175, 0.00628061, 0.00614359,
#        0.00601052, 0.00588126, 0.00575569, 0.00563367, 0.00551507,
#        0.00539977, 0.00528767, 0.00517865, 0.00507261, 0.00496944,
#        0.00486905])

# %%
a_ene = pd.DataFrame([-42.968477,-43.154564,-43.285813,-43.365873,-43.398229,-43.386254,-43.332929,-43.241342,-43.114322,-42.954578,-42.764700,-42.547132,-42.304215,-42.038127,-41.750968,-41.444806],np.arange(5.30,5.91,0.04)**(-3))

# %%
a_ene.rename(columns={0:'能量'},inplace=True)

# %%
ene = a_ene['能量']

# %%
ene
# Out:
# 0.006717   -42.968477
# 0.006567   -43.154564
# 0.006422   -43.285813
# 0.006281   -43.365873
# 0.006144   -43.398229
# 0.006011   -43.386254
# 0.005881   -43.332929
# 0.005756   -43.241342
# 0.005634   -43.114322
# 0.005515   -42.954578
# 0.005400   -42.764700
# 0.005288   -42.547132
# 0.005179   -42.304215
# 0.005073   -42.038127
# 0.004969   -41.750968
# 0.004869   -41.444806
# Name: 能量, dtype: float64

# %%
a_ene.plot(color='k',legend='')
plt.xlabel(r'晶格常数$^{-3}$/$\mathrm \AA^{-3}$')
plt.ylabel('能量/eV')
plt.yticks(fontproperties = 'Times New Roman', size = 14)
plt.xticks(fontproperties = 'Times New Roman', size = 14)
plt.scatter(np.arange(5.30,5.90,0.04)**(-3),ene,color='k')
plt.annotate("最小值",xy=(5.473**(-3),-43.39),xytext=(5.473**(-3)+0.00001,-43.2),arrowprops=dict(arrowstyle='->',connectionstyle='arc3'))
#plt.savefig('/home/thoughts/git/thesis/fini-thesis/fig/a-ene.png',bbox_inches='tight')
plt.savefig('C:/Users/thoughts/Documents/GitHub/thesis/defense/a-ene.png',bbox_inches='tight')
#plt.legend('total energy',loc='best')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# c:\users\thoughts\appdata\local\programs\python\python38\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2597         try:
# -> 2598             result = self._expression.parseString(s)
#    2599         except ParseBaseException as err:
#
# c:\users\thoughts\appdata\local\programs\python\python38\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# c:\users\thoughts\appdata\local\programs\python\python38\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# ...

# %%
plt.bar(np.arange(2015,2020,1),[18.0,19.5,20.8,22.1,23.4],fc='c',width=0.5)
plt.xlabel('年份')
plt.ylabel('百分比/\%')
plt.ylim(0,25)
for a,b in zip(np.arange(2015,2020,1),[18.0,19.5,20.8,22.1,23.4]):
    plt.text(a, b+0.05, b, ha='center', va= 'bottom',fontsize=14) 
plt.savefig('/home/thoughts/git/thesis/fini-thesis/fig/clean-ene-prc.png',bbox_inches='tight')
plt.show()

# %%
np.arange(1,3,1)
# Out:
# array([1, 2])
